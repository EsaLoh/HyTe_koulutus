# %% [markdown]
# <a href="https://colab.research.google.com/github/EsaLoh/HyTe_koulutus/blob/master/Hyvinvointikysely_paivat_1_5_kapeamuoto_taulukko.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
dat = pd.read_csv("https://raw.githubusercontent.com//EsaLoh/HyTe_koulutus/master/Kapeamuoto.csv", encoding='latin-1')

dat[0:30] #tulostetaan otsikko ja ensimmäinen rivi tarkistuksen vuoksi
# Out:
#    Aikaleima  Nimimerkki  Arvo                        Kysymys
# 0   1.6.2020      123098     4     Tunnen itseni onnelliseksi
# 1   1.6.2020        9253     4     Tunnen itseni onnelliseksi
# 2   1.6.2020      222426     4     Tunnen itseni onnelliseksi
# 3   1.6.2020      145789     4     Tunnen itseni onnelliseksi
# 4   1.6.2020       21084     4     Tunnen itseni onnelliseksi
# 5   1.6.2020        7968     5     Tunnen itseni onnelliseksi
# 6   1.6.2020  2905202010     4     Tunnen itseni onnelliseksi
# 7   1.6.2020          29     3     Tunnen itseni onnelliseksi
# 8   1.6.2020        1500     3     Tunnen itseni onnelliseksi
# 9   1.6.2020      369369     3     Tunnen itseni onnelliseksi
# 10  2.6.2020      290520     3     Tunnen itseni onnelliseksi
# 11  2.6.2020         907     1     Tunnen itseni onnelliseksi
# 12  2.6.2020       34725     4     Tunnen itseni onnelliseksi
# 13  3.6.2020        7469     2     Tunnen itseni onnelliseksi
# ...

# %%
dat2 = dat[dat.Kysymys=='Tunnen hallitsevani omaa elamaani']
dat2
# Out:
#    Aikaleima  Nimimerkki  Arvo                            Kysymys
# 78  4.6.2020      123098     4  Tunnen hallitsevani omaa elamaani
# 79  4.6.2020          29     4  Tunnen hallitsevani omaa elamaani
# 80  4.6.2020       21084     3  Tunnen hallitsevani omaa elamaani
# 81  4.6.2020      145789     4  Tunnen hallitsevani omaa elamaani
# 82  4.6.2020  2905202010     3  Tunnen hallitsevani omaa elamaani
# 83  4.6.2020      222426     3  Tunnen hallitsevani omaa elamaani
# 84  4.6.2020        9253     3  Tunnen hallitsevani omaa elamaani
# 85  4.6.2020         907     1  Tunnen hallitsevani omaa elamaani
# 86  4.6.2020        7968     5  Tunnen hallitsevani omaa elamaani
# 87  4.6.2020      369369     3  Tunnen hallitsevani omaa elamaani
# 88  4.6.2020        1500     3  Tunnen hallitsevani omaa elamaani
# 89  6.6.2020      290520     4  Tunnen hallitsevani omaa elamaani
# 90  6.6.2020         704     3  Tunnen hallitsevani omaa elamaani

# %%
sns.set(style="whitegrid", rc={'figure.figsize':(16,8)})

ax = sns.barplot(x=dat.Nimimerkki, y=dat2.Arvo, data=dat2)

# %%
dat3 = dat[dat.Nimimerkki==7968]
dat3
# Out:
#     Aikaleima  ...                                            Kysymys
# 5    1.6.2020  ...                         Tunnen itseni onnelliseksi
# 19   1.6.2020  ...                      Nukuin riittavasti viime yona
# 38   2.6.2020  ...                         Koen usein rauhan tunnetta
# 51   2.6.2020  ...  Tunnen useamman kerran paivassa iloa tyytyvais...
# 62   3.6.2020  ...  Minulla on aikaa laheisilleni ystavilleni ja m...
# 74   3.6.2020  ...  Minulle on tarkeaa viettaa kahvi ja lounastauk...
# 86   4.6.2020  ...                  Tunnen hallitsevani omaa elamaani
# 99   4.6.2020  ...   Tiesin aamulla mita tulen tekemaan paivan aikana
# 105  5.6.2020  ...                             Tunnen etta voin hyvin
# 117  5.6.2020  ...                     Soin eilen terveellista ruokaa
#
# [10 rows x 4 columns]

# %%
sns.set(style="whitegrid", rc={'figure.figsize':(40,16)})

ax = sns.barplot(x=dat.Kysymys, y=dat3.Arvo, data=dat3)

# %%
fiilis = dat[dat.Kysymys=='Nukuin riittavasti viime yona']
teema = dat[dat.Kysymys=='Tunnen itseni onnelliseksi']

Fiilis = pd.Series(fiilis.Arvo)
Teema = pd.Series(teema.Arvo)

from numpy.polynomial.polynomial import polyfit
b, m = polyfit(Fiilis, Teema, 1)

plt.plot(Fiilis, Teema, '.')
plt.plot(Fiilis, b + m * Fiilis, '-')
plt.title("Teema vs Fiilis")
plt.show()
#plt.scatter(Fiilis, Teema)

# %%
fiilis = dat[dat.Kysymys=='Tunnen useamman kerran paivassa iloa tyytyvaisyytta tai merkityksellisyytta']
teema = dat[dat.Kysymys=='Koen usein rauhan tunnetta']

Fiilis = pd.Series(fiilis.Arvo)
Teema = pd.Series(teema.Arvo)

from numpy.polynomial.polynomial import polyfit
b, m = polyfit(Fiilis, Teema, 1)

plt.plot(Fiilis, Teema, '.')
plt.plot(Fiilis, b + m * Fiilis, '-')
plt.title("Teema vs Fiilis")
plt.show()
#plt.scatter(Fiilis, Teema)

# %%
fiilis = dat[dat.Kysymys=='Minulle on tarkeaa viettaa kahvi ja lounastauko tyokavereiden seurassa']
teema = dat[dat.Kysymys=='Minulla on aikaa laheisilleni ystavilleni ja muille tutuilleni']

Fiilis = pd.Series(fiilis.Arvo)
Teema = pd.Series(teema.Arvo)

from numpy.polynomial.polynomial import polyfit
b, m = polyfit(Fiilis, Teema, 1)

plt.plot(Fiilis, Teema, '.')
plt.plot(Fiilis, b + m * Fiilis, '-')
plt.title("Teema vs Fiilis")
plt.show()
#plt.scatter(Fiilis, Teema)

# %%
fiilis = dat[dat.Kysymys=='Tiesin aamulla mita tulen tekemaan paivan aikana']
teema = dat[dat.Kysymys=='Tunnen hallitsevani omaa elamaani']

Fiilis = pd.Series(fiilis.Arvo)
Teema = pd.Series(teema.Arvo)

from numpy.polynomial.polynomial import polyfit
b, m = polyfit(Fiilis, Teema, 1)

plt.plot(Fiilis, Teema, '.')
plt.plot(Fiilis, b + m * Fiilis, '-')
plt.title("Teema vs Fiilis")
plt.show()
#plt.scatter(Fiilis, Teema)

# %%
fiilis = dat[dat.Kysymys=='Soin eilen terveellista ruokaa']
teema = dat[dat.Kysymys=='Tunnen etta voin hyvin']

Fiilis = pd.Series(fiilis.Arvo)
Teema = pd.Series(teema.Arvo)

from numpy.polynomial.polynomial import polyfit
b, m = polyfit(Fiilis, Teema, 1)

plt.plot(Fiilis, Teema, '.')
plt.plot(Fiilis, b + m * Fiilis, '-')
plt.title("Teema vs Fiilis")
plt.show()
#plt.scatter(Fiilis, Teema)
